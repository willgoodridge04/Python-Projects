# %%
# Importing libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots

# Taking a look at the data

df = pd.read_csv(r'C:\Users\12549\Downloads\movies.csv')

# %%
# checking out the data

df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year  yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986            0
# 1        27      103    7.8  1605  264740    1970  1986            0
# 2        23      110    6.9  2345  236909    1852  1986            0
# 3        33      137    8.4  2192  540152    1629  1986            0
# 4        36       90    6.9  1139   36636    2549  1986            0

# %%
# Finding any nulls in the data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
# What are the data types?

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
# Changing budget and gross revenue columns to integers

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year  yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986            0
# 1        27      103    7.8  1605  264740    1970  1986            0
# 2        23      110    6.9  2345  236909    1852  1986            0
# 3        33      137    8.4  2192  540152    1629  1986            0
# 4        36       90    6.9  1139   36636    2549  1986            0

# %%
# Creating a correct Year column

df['yearcorrect'] = df['released'].astype(str).str[:4]

df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986          39
# 1        27      103    7.8  1605  264740    1970  1986          27
# 2        23      110    6.9  2345  236909    1852  1986          23
# 3        33      137    8.4  2192  540152    1629  1986          33
# 4        36       90    6.9  1139   36636    2549  1986          36

# %%
df = df.sort_values(by = ['gross'], inplace = False, ascending = False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Looking for any potential duplicates to drop

df['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 5288    2178
# 3486    2177
# 6084    2176
# 3225    2175
# 2707    2174
#         ...
# 3527       4
# 5466       3
# 2815       2
# 3208       1
# 3832       0
# Name: company, Length: 2179, dtype: int16

# %%
df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986          39
# 1        27      103    7.8  1605  264740    1970  1986          27
# 2        23      110    6.9  2345  236909    1852  1986          23
# 3        33      137    8.4  2192  540152    1629  1986          33
# 4        36       90    6.9  1139   36636    2549  1986          36

# %%
# Potential high correlation between movie budget and gross earnings
# Potential high correlation between company and gross earnings

# %%
# Scatter plot with budget vs gross revenue

plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

plt.show()

# %%
df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986          39
# 1        27      103    7.8  1605  264740    1970  1986          27
# 2        23      110    6.9  2345  236909    1852  1986          23
# 3        33      137    8.4  2192  540152    1629  1986          33
# 4        36       90    6.9  1139   36636    2549  1986          36

# %%
# Plot budget vs gross using seaborn for linear regression

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {"color": "red"}, line_kws = {"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Searching for correlations

# %%
# Pearson Correlation

df.corr(method = 'pearson')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
correlation_matrix = df.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Looking at company correlation to gross earnings

df.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986          39
# 1        27      103    7.8  1605  264740    1970  1986          27
# 2        23      110    6.9  2345  236909    1852  1986          23
# 3        33      137    8.4  2192  540152    1629  1986          33
# 4        36       90    6.9  1139   36636    2549  1986          36

# %%
# Numerically categorizing non-integer columns for correlations
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.0      665       54      2192      1   52287414.0  4661       8
# 1   6000000.0     1680       54      1296      4   70136369.0  1821       7
# 2  15000000.0     1680       54      2645      0  179800601.0  6203       6
# 3  18500000.0     2062       54      1066      0   85160248.0   295       8
# 4   9000000.0     2122       54      2123      1   18564613.0  1872       6
#
#    released  runtime  score  star   votes  writer  year  yearcorrect
# 0        39       89    8.1  2454  299174    3716  1986         1726
# 1        27      103    7.8  1605  264740    1970  1986         1593
# 2        23      110    6.9  2345  236909    1852  1986         1446
# 3        33      137    8.4  2192  540152    1629  1986         1660
# 4        36       90    6.9  1139   36636    2549  1986         1693

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                budget   company   country  director     genre     gross  \
# budget       1.000000  0.187205  0.137635  0.011602 -0.346794  0.712196
# company      0.187205  1.000000  0.107950  0.004320 -0.068330  0.187220
# country      0.137635  0.107950  1.000000  0.003699 -0.042793  0.149988
# director     0.011602  0.004320  0.003699  1.000000 -0.027669 -0.011429
# genre       -0.346794 -0.068330 -0.042793 -0.027669  1.000000 -0.242676
# gross        0.712196  0.187220  0.149988 -0.011429 -0.242676  1.000000
# name         0.028712  0.018098  0.025020  0.001906  0.018062  0.022768
# rating      -0.119660 -0.062250  0.057979  0.021926  0.100960 -0.135538
# released     0.276635  0.027898 -0.062609  0.001440 -0.039179  0.178564
# runtime      0.268226  0.033058 -0.081796  0.026779 -0.041357  0.224579
# score        0.042145 -0.010426 -0.174414  0.017130  0.056234  0.165693
# star        -0.015062 -0.003160 -0.014569  0.039813  0.008140  0.008381
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.187205
#              country        0.137635
#              director       0.011602
#              genre         -0.346794
#              gross          0.712196
#              name           0.028712
#              rating        -0.119660
#              released       0.276635
#              runtime        0.268226
#              score          0.042145
#              star          -0.015062
#              votes          0.503924
#              writer        -0.015611
#              year           0.291009
#              yearcorrect    0.274820
# company      budget         0.187205
#              company        1.000000
#              country        0.107950
#              director       0.004320
#              genre         -0.068330
#              gross          0.187220
#              name           0.018098
#              rating        -0.062250
#              released       0.027898
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.346794
# budget       genre         -0.346794
# gross        genre         -0.242676
# genre        gross         -0.242676
# score        country       -0.174414
# country      score         -0.174414
# votes        genre         -0.150519
# genre        votes         -0.150519
# rating       gross         -0.135538
# gross        rating        -0.135538
# budget       rating        -0.119660
# rating       budget        -0.119660
# country      runtime       -0.081796
# runtime      country       -0.081796
# genre        company       -0.068330
# company      genre         -0.068330
# country      yearcorrect   -0.062707
# yearcorrect  country       -0.062707
# country      released      -0.062609
# released     country       -0.062609
# rating       company       -0.062250
# company      rating        -0.062250
# year         genre         -0.046259
# genre        year          -0.046259
# country      year          -0.045204
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes        budget         0.503924
# budget       votes          0.503924
# votes        gross          0.662457
# gross        votes          0.662457
#              budget         0.712196
# budget       gross          0.712196
# released     year           0.996187
# year         released       0.996187
# yearcorrect  year           0.996229
# year         yearcorrect    0.996229
# yearcorrect  released       0.999389
# released     yearcorrect    0.999389
# budget       budget         1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# ...

# %%
# Votes and budget have the highest correlation to gross earnings

# Company has low correlation
